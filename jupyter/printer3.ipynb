# %%
#게임만들기
import random
str = ["스타크래프트"
       "워크래프트"
       "헬다이버즈"
       "배틀그라운드"
       "마인크래프트"]
print('타자연습 게임입니다.')
input('엔터를 누르면 시작합니다')

target = random.choice(str)
print('\n다음 문장을 그대로 입력하세요:\n')
print(f'{target}\n')

input('준비되면 ENTER를 누르시오')


#print(a)
#abc=['a','b','c','d','e']
#abc = ['a', 'b', 'c', 'd', 'e']
#random.shuffle(abc) abc=['a','b','c','d','e'] 랜덤하게 섞여서 나옴
#random.choice(abc)
#import time
import time

time.time()
time.localtime(time.time())

lt = time.localtime(time.time())
time.asctime(lt)


start_time = time.time()#시간측저이작
trial = 0
while True:
        
    typed = (input("\n입력"))# 사용자 입력 받기

    end_time = time.time()#시간 측정 종료

    elapsed = end_time - start_time
    #print(elapsed)

    #correct = 0
    #for i in 범주(질문 문장의 길이,입력한 문장의 길이)):
    #if 질문문장 단어 == 입력문장 단어:
    #correct += 1
    correct = 0#정확도 계산

    for i in range(min(len(target),len(typed))):
        if target[i] == typed[i]:
            correct += 1

    total = max(len(target), len(typed))#오류수정
    accuracy = correct / len(a) * 100
    speed = len(typed) / elapsed * 60 # 분당 타자 수(cpm)

    if accuracy == 100:
        print("완료했어요.")
        break
    else:
        print("다시 시도해보세요")
        trial += 1

#결과 출력
print("\n결과")
print(f"걸린 시간:{elapsed:.2f}초")
print(f"정확도: {accuracy:.2f}%")
print(f"시도 횟수 {trial:.2f}")
print(f"타자 속도: {speed:.2f} 차/분")
    
#추가요구사항 오타가 없을떄까지 입력을 받도록 수정
#정확도 대신 오타 횟수 출력

# %%
#게임만들기
import random
str = ["스타크래프트",
       "워크래프트",
       "헬다이버즈",
       "배틀그라운드",
       "마인크래프트"]
print('타자연습 게임입니다.')
input('엔터를 누르면 시작합니다')

target = random.choice(str)
print('\n다음 문장을 그대로 입력하세요:\n')
print(f'{target}\n')

input('준비되면 ENTER를 누르시오')


#print(a)
#abc=['a','b','c','d','e']
#abc = ['a', 'b', 'c', 'd', 'e']
#random.shuffle(abc) abc=['a','b','c','d','e'] 랜덤하게 섞여서 나옴
#random.choice(abc)
#import time
import time

time.time()
time.localtime(time.time())

lt = time.localtime(time.time())
time.asctime(lt)


start_time = time.time()#시간측저이작
trial = 0
while True:
        
    typed = (input("\n입력"))# 사용자 입력 받기

    end_time = time.time()#시간 측정 종료

    elapsed = end_time - start_time
    #print(elapsed)

    #correct = 0
    #for i in 범주(질문 문장의 길이,입력한 문장의 길이)):
    #if 질문문장 단어 == 입력문장 단어:
    #correct += 1
    correct = 0#정확도 계산

    for i in range(min(len(target),len(typed))):
        if target[i] == typed[i]:
            correct += 1

    total = max(len(target), len(typed))#오류수정
    accuracy = correct / len(a) * 100
    speed = len(typed) / elapsed * 60 # 분당 타자 수(cpm)

    if accuracy == 100:
        print("완료했어요.")
        break
    else:
        print("다시 시도해보세요")
        trial += 1

#결과 출력
print("\n결과")
print(f"걸린 시간:{elapsed:.2f}초")
print(f"정확도: {accuracy:.2f}%")
print(f"시도 횟수 {trial:.2f}")
print(f"타자 속도: {speed:.2f} 차/분")
    
#추가요구사항 오타가 없을떄까지 입력을 받도록 수정
#정확도 대신 오타 횟수 출력

# %%
#게임만들기
import random
str = ["스타크래프트",
       "워크래프트",
       "헬다이버즈",
       "배틀그라운드",
       "마인크래프트"]
print('타자연습 게임입니다.')
input('엔터를 누르면 시작합니다')
target = random.choice(str)
print('\n다음 문장을 그대로 입력하세요:\n')
print(f'{target}\n')
input('준비되면 ENTER를 누르시오')
#print(a)
#abc=['a','b','c','d','e']
#abc = ['a', 'b', 'c', 'd', 'e']
#random.shuffle(abc) abc=['a','b','c','d','e'] 랜덤하게 섞여서 나옴
#random.choice(abc)
#import time
import time

time.time()
time.localtime(time.time())

lt = time.localtime(time.time())
time.asctime(lt)


start_time = time.time()#시간측저이작
trial = 0
while True:
        
    typed = (input("\n입력"))# 사용자 입력 받기

    end_time = time.time()#시간 측정 종료

    elapsed = end_time - start_time
    #print(elapsed)

    #correct = 0
    #for i in 범주(질문 문장의 길이,입력한 문장의 길이)):
    #if 질문문장 단어 == 입력문장 단어:
    #correct += 1
    correct = 0#정확도 계산

    for i in range(min(len(target),len(typed))):
        if target[i] == typed[i]:
            correct += 1

    total = max(len(target), len(typed))#오류수정
    accuracy = correct / len(a) * 100
    speed = len(typed) / elapsed * 60 # 분당 타자 수(cpm)

    if accuracy == 100:
        print("완료했어요.")
        break
    else:
        print("다시 시도해보세요")
        trial += 1

#결과 출력
print("\n결과")
print(f"걸린 시간:{elapsed:.2f}초")
print(f"정확도: {accuracy:.2f}%")
print(f"시도 횟수 {trial:.2f}")
print(f"타자 속도: {speed:.2f} 차/분")
    
#추가요구사항 오타가 없을떄까지 입력을 받도록 수정
#정확도 대신 오타 횟수 출력

# %%
#랜덤 문장 출력 Hint 2중 리스트 Random함수
list = [1,2,3,4,5]
list2 =["a","b","c","d","e"]
list3 = [1,[list2],3,4,[list]]

list4 = random.choice(list3)
list2

# %%
proverbs = [
         ("호랑이 굴에","들어가야 산다"),("등잔 밑이","어둡다"),("가는 말이","고와야 오는 말이 곱다"),
        ("고생 끝에","낙이 온다"),("원숭이도","나무에서 떨어진다"),("티끌 모아","태산"),
        ("백문이","불여일견"),("똥 묻은 개가","겨 묻은 개 나무란다"),("바늘 도둑이","소 도둑 된다")
]
print("속담 맞추기 게임입니다")
input("ENTER를 누르면 시작합니다")
score = 0
trial = 0
for total in range(5):
    front,back = random.choice(proverbs)#랜덤함수 출력 random.
    print(f"속담:\"{front}?\"")

    answer = input("뒷부분을 입력하세요:").strip()
    correct1 = 0
    if answer == back:
        print("정답\n")
        score += 1      
    else:#힌트제공
        hint = back[0] #첫 글자
        length = len(back)
        print(f"오답입니다. 힌트: '{hint}'로 시작하시오")
        answer = input("힌트를 보고 다시 입력하세요:").strip()
        if answer == back:
            print('정답\n')
            score += 1
        else:
            print(f"오답 정답은:\"{back}\"입니다\n")
total += 1
print(f"\n게임 종료! 당신의 총 {total}중 {score}문제 정답입니다")
#오답을 입력했을떄, 정답의 일부 를 힌트로 보여주는 기능추가
#힌트를 보고 한번 더 입력하도록 기능 추가
# Out:
# 속담 맞추기 게임입니다
# 속담:"똥 묻은 개가?"
# 오답입니다. 힌트: '겨'로 시작하시오
# 오답 정답은:"겨 묻은 개 나무란다"입니다
#
# 속담:"고생 끝에?"
# 오답입니다. 힌트: '낙'로 시작하시오
# 오답 정답은:"낙이 온다"입니다
#
# 속담:"가는 말이?"
# 오답입니다. 힌트: '고'로 시작하시오
# 오답 정답은:"고와야 오는 말이 곱다"입니다
#
# 속담:"등잔 밑이?"
# 오답입니다. 힌트: '어'로 시작하시오
# 오답 정답은:"어둡다"입니다
#
# 속담:"원숭이도?"
# 오답입니다. 힌트: '나'로 시작하시오
# 오답 정답은:"나무에서 떨어진다"입니다
#
#
# 게임 종료! 당신의 총 5중 0문제 정답입니다

# %%
def check_answer(answer, back):
    if answer == back:
        return True
    else:
        return False

# %%
#QR코드 생성
#시작 - 랜덤 문장 출력 -정답 코드 생성 - 정답빅 - 계속? -종료
#pip install qrcode pillow 큐알 생성 모듈
#필요한 모듈 어케 찾음  =pypi.org 사이트
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[292], line 15
#      13 import qrcode
#      14 img = qrcode.make("<경준이 카누 꼬불침>")
# ---> 15 img.saver("qrcode.png")
#
# File c:\Users\장병훈\AppData\Local\Programs\Python\Python313\Lib\site-packages\qrcode\image\pil.py:57, in PilImage.__getattr__(self, name)
#      56 def __getattr__(self, name):
# ---> 57     return getattr(self._img, name)
#
# AttributeError: 'Image' object has no attribute 'saver'

# %%
oldtext = [
         ("호랑이 굴에","들어가야 산다"),("등잔 밑이","어둡다"),("가는 말이","고와야 오는 말이 곱다"),
        ("고생 끝에","낙이 온다"),("원숭이도","나무에서 떨어진다"),("티끌 모아","태산"),
        ("백문이","불여일견"),("똥 묻은 개가","겨 묻은 개 나무란다"),("바늘 도둑이","소 도둑 된다")
]
random = random.choice(oldtext)

import qrcode
img = qrcode.make(random)
img.save("qrcode.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[300], line 6
#       1 oldtext = [
#       2          ("호랑이 굴에","들어가야 산다"),("등잔 밑이","어둡다"),("가는 말이","고와야 오는 말이 곱다"),
#       3         ("고생 끝에","낙이 온다"),("원숭이도","나무에서 떨어진다"),("티끌 모아","태산"),
#       4         ("백문이","불여일견"),("똥 묻은 개가","겨 묻은 개 나무란다"),("바늘 도둑이","소 도둑 된다")
#       5 ]
# ----> 6 random = random.choice(oldtext)
#       8 import qrcode
#       9 img = qrcode.make(random)
#
# AttributeError: 'tuple' object has no attribute 'choice'
